# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\umschueler\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
values = [0, 1, 2, 3, 4, 5, 6, 7]
squares = [value ** 2 for value in values]
plt.plot(values, squares)
plt.show()

# %%
plt.scatter(values, squares)
plt.show()

# %%
values = list(range(100))
pows = [pow(value, 3) for value in values]
plt.scatter(values, pows)
plt.show()

# %%
plt.scatter(values, pows, c=pows, cmap=plt.cm.Blues, edgecolor='none', s=10)

# %%
values = list(range(50))
squares = [pow(value, 2) for value in values]
cubes = [pow(value, 3) for value in values]

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
ax1.scatter(values, squares)
ax1.set_title('Square numbers')
ax2.plot(values, cubes)
ax2.set_title('Cube numbers')
plt.show()

# %%
values = list(range(10))
squares = [pow(value, 2) for value in values]
cubes = [pow(value, 3) for value in values]

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.scatter(values, squares)
ax1.set_title('Square numbers')
ax2.plot(values, cubes)
ax2.set_title('Cube numbers')
plt.show()

# %%
data = {
    'Year': [2001, 2002, 2003, 2004, 2005, 2006],
    'Sales':[100, 150, 130, 180, 210, 230]
}

df = pd.DataFrame(data)
df.plot(x='Year', y='Sales', kind='line')
plt.title('Yearly Sales')
plt.show()

# %%
data = {
    'Year': [2001, 2002, 2003, 2004, 2005, 2006],
    'Sales':[100, 150, 130, 180, 210, 230]
}

df = pd.DataFrame(data)
df.plot(x='Year', y='Sales', kind='bar')
plt.title('Yearly Sales')
plt.show()

# %%
data = {
    'Year': [2001, 2002, 2003, 2004, 2005, 2006],
    'Sales':[100, 150, 130, 180, 210, 230]
}

df = pd.DataFrame(data)
df.plot(x='Year', y='Sales', kind='area')
plt.title('Yearly Sales')
plt.show()

# %%
data = {
    'Year': [2001, 2002, 2003, 2004, 2005, 2006],
    'Sales':[100, 150, 130, 180, 210, 230]
}

df = pd.DataFrame(data)
df.plot(y='Sales', kind='pie', labels=df['Year'], autopct='%1.1f%%')
plt.title('Yearly Sales')
plt.show()

# %%
data = {
    'Age':[25, 28, 32, 41, 42, 42, 50, 59, 60]
}

df = pd.DataFrame(data)
df.plot(y='Age', kind='hist')
plt.title('Age distribution')
plt.show()

# %%
data = {
    'Category': ['FIEST', 'FIEST', 'SECOND', 'SECOND', 'THIRD', 'THIRD', 'SECOND'],
    'Value': [10, 20, 25, 45, 45, 50, 50]
}

df = pd.DataFrame(data)
df
# Out:
#   Category  Value
# 0    FIEST     10
# 1    FIEST     20
# 2   SECOND     25
# 3   SECOND     45
# 4    THIRD     45
# 5    THIRD     50
# 6   SECOND     50

# %%
df.boxplot(by='Category', column='Value')
plt.title('Values distribution by Category')
plt.show()

# %%
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May'],
    'Week 1 Temp': [6, 10, 12, 14, 17],
    'Week 2 Temp': [8, 12, 13, 14, 18],
    'Week 3 Temp': [9, 11, 14, 16, 20],
    'Week 4 Temp': [8, 12, 15, 18, 22]
}

df = pd.DataFrame(data)
df.head()
# Out:
#   Month  Week 1 Temp  Week 2 Temp  Week 3 Temp  Week 4 Temp
# 0   Jan            6            8            9            8
# 1   Feb           10           12           11           12
# 2   Mar           12           13           14           15
# 3   Apr           14           14           16           18
# 4   May           17           18           20           22

# %%
df.set_index('Month', inplace=True)
df.head()
# Out:
#        Week 1 Temp  Week 2 Temp  Week 3 Temp  Week 4 Temp
# Month
# Jan              6            8            9            8
# Feb             10           12           11           12
# Mar             12           13           14           15
# Apr             14           14           16           18
# May             17           18           20           22

# %%
sns.heatmap(df, cmap='coolwarm', annot=True)
plt.title('Weekly temperature data')
plt.show()
